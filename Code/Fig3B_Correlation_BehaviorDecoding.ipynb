# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Fig3B_Correlation.csv")
data
# Out:
#     Behavioral Accuracy (Expected-Uninformative)  \
# 0                                       0.000100
# 1                                       0.043887
# 2                                       0.096117
# 3                                       0.075839
# 4                                       0.085233
# 5                                       0.023823
# 6                                       0.068790
# 7                                       0.070648
# 8                                       0.054311
# 9                                       0.085600
# 10                                      0.057889
# 11                                      0.037211
# 12                                      0.068200
# 13                                      0.045111
# 14                                      0.050411
# 15                                      0.046522
# 16                                      0.032411
# 17                                      0.036220
# 18                                      0.039440
# 19                                      0.058664
# 20                                      0.091633
# 21                                      0.086220
# 22                                      0.078876
# 23                                      0.075432
# 24                                      0.092356
# 25                                      0.000100
# 26                                      0.043887
# 27                                      0.096117
# 28                                      0.075839
# 29                                      0.085233
# 30                                      0.023823
# 31                                      0.068790
# 32                                      0.070648
# 33                                      0.054311
# 34                                      0.085600
# 35                                      0.057889
# 36                                      0.037211
# 37                                      0.068200
# 38                                      0.045111
# 39                                      0.050411
# 40                                      0.046522
# 41                                      0.032411
# 42                                      0.036220
# 43                                      0.039440
# 44                                      0.058664
# 45                                      0.091633
# 46                                      0.086220
# 47                                      0.078876
# 48                                      0.075432
# 49                                      0.092356
#
#     Classification Accuracy (Expected-Uninformative)          Region
# 0                                           0.082000  Contra-lateral
# 1                                           0.045200  Contra-lateral
# 2                                           0.072340  Contra-lateral
# 3                                           0.054300  Contra-lateral
# 4                                           0.093200  Contra-lateral
# 5                                           0.032100  Contra-lateral
# 6                                           0.078000  Contra-lateral
# 7                                           0.060210  Contra-lateral
# 8                                           0.073400  Contra-lateral
# 9                                           0.103000  Contra-lateral
# 10                                          0.043600  Contra-lateral
# 11                                          0.048200  Contra-lateral
# 12                                          0.087320  Contra-lateral
# 13                                          0.054210  Contra-lateral
# 14                                          0.058900  Contra-lateral
# 15                                          0.043210  Contra-lateral
# 16                                          0.043215  Contra-lateral
# 17                                          0.054321  Contra-lateral
# 18                                          0.054670  Contra-lateral
# 19                                          0.043200  Contra-lateral
# 20                                          0.109000  Contra-lateral
# 21                                          0.072300  Contra-lateral
# 22                                          0.098210  Contra-lateral
# 23                                          0.084711  Contra-lateral
# 24                                          0.112356  Contra-lateral
# 25                                          0.095766    Ipsi-lateral
# 26                                         -0.005870    Ipsi-lateral
# 27                                         -0.037835    Ipsi-lateral
# 28                                         -0.091306    Ipsi-lateral
# 29                                          0.021095    Ipsi-lateral
# 30                                          0.044054    Ipsi-lateral
# 31                                          0.070236    Ipsi-lateral
# 32                                          0.091179    Ipsi-lateral
# 33                                         -0.040451    Ipsi-lateral
# 34                                         -0.059230    Ipsi-lateral
# 35                                          0.009102    Ipsi-lateral
# 36                                         -0.022569    Ipsi-lateral
# 37                                          0.005557    Ipsi-lateral
# 38                                         -0.020952    Ipsi-lateral
# 39                                          0.138250    Ipsi-lateral
# 40                                         -0.026329    Ipsi-lateral
# 41                                         -0.072869    Ipsi-lateral
# 42                                          0.040392    Ipsi-lateral
# 43                                          0.039556    Ipsi-lateral
# 44                                          0.002810    Ipsi-lateral
# 45                                          0.084797    Ipsi-lateral
# 46                                          0.056290    Ipsi-lateral
# 47                                         -0.022917    Ipsi-lateral
# 48                                          0.026290    Ipsi-lateral
# 49                                          0.032917    Ipsi-lateral

# %%
reg_dct = ['Contra-lateral', 'Ipsi-lateral']
fig, ax = plt.subplots()

#adjustable colors
colors = ["#6eb574","grey"]
colors = ["black","grey"]
colors = ["#19700a","grey"]


da0 = data[data['Region']==reg_dct[0]]
da1 = data[data['Region']==reg_dct[1]]
x = "Behavioral Accuracy (Expected-Uninformative)"
y = "Classification Accuracy (Expected-Uninformative)"
axis = sns.regplot(x=x,y=y, data=da0,
                    scatter_kws={"color": colors[0]}, 
                    line_kws={"color": colors[0]}, 
                    label='small', ax=ax)
sns.regplot(x=x,y=y, data=da1,
                    scatter_kws={"color": colors[1]}, 
                    line_kws={"color": colors[1]}, 
                    label='small', ax=ax)
# axis.axes.set_title(reg_dct[idx].replace('-','') + ' S1',fontsize=30, y = 1.05)
axis.set_ylabel('Δ Decoding Accuracy (%)',fontsize=30,fontname='Arial')
axis.set_xlabel('Δ Accuracy (% Correct)',fontsize=30,fontname='Arial')
#axis.set_xlabel('')
axis.tick_params(labelsize=10)
axis.spines['right'].set_visible(False)
axis.spines['top'].set_visible(False)
#axis.spines['bottom'].set_visible(False)
axis.spines['left'].set_linewidth(2)
axis.spines['bottom'].set_linewidth(2)
axis.set_ylim([-0.1,0.15])
axis.set_yticks([-0.1,-0.05,0,0.05,0.1,0.15], fontname='Arial')
axis.set_yticklabels(['-10','-5','0','5','10','15'],fontname='Arial')
axis.set_xlim([-0.001,0.101])
axis.set_xticks([0.05,0.1], fontname='Arial')
axis.set_xticklabels(['5','10'],fontname='Arial')
axis.tick_params(axis='both', which='major', direction='in',length=12, labelsize=24, width=2)

    
plt.subplots_adjust(left=1.5,
                bottom=0.1, 
                right=2.2, 
                top=0.9, 
                wspace=0.4, 
                hspace=0.4)

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles,reg_dct, fontsize = 18, frameon=False, loc=(1.04, 0))
plt.legend().remove()


fig.set_size_inches([7,6])

fig.savefig("Fig3C_Reg_comb.jpg",dpi=600,bbox_inches='tight')
plt.savefig('Fig3C_Reg_comb.eps', format='eps',dpi=600)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
